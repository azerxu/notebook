# %% [markdown]
# Command to translate ipynb file to reveal slides
# ================================================
#
# ipython nbconvert --to slides --RevealHelpTransformer.enabled=True --RevealHelpTransformer.url_prefix=reveal.js Hi\ Sample\ Library.ipynb

# %%
cd ~/sources/bamstat/interval/
# Out:
# /home/azer/sources/bamstat/interval

# %%
from IPython.display import SVG

# %% [markdown]
# 说明:
# ====
#     将各个库的原序列mapping到Scaffold上， 然后统计fragment大小

# %% [markdown]
# Library PE 180 for Hi sample of Scaffold
# ----------------------------------------

# %%
SVG(filename='scaf.hi.pe.180.size.stat.svg')

# %% [markdown]
# Library PE 450 for Hi sample of Scaffold
# ----------------------------------------

# %%
SVG(filename='scaf.hi.pe.450.size.stat.svg')

# %% [markdown]
# Library MP 5K for Hi sample of Scaffold
# ---------------------------------------

# %%
SVG(filename='scaf.hi.mp.5k.size.stat.svg')

# %% [markdown]
# Library MP 20K for Hi sample of Scaffold
# ----------------------------------------

# %%
SVG(filename='scaf.hi.mp.20k.size.stat.svg')
